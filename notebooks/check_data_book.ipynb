# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from config import DATA_PATH, MODEL_PATH

# %%
df = pd.read_csv(DATA_PATH)

print(df.info())
print(df.describe())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Server_ID          1000 non-null   object
#  1   Data_Center        1000 non-null   object
#  2   Purchase_Date      1000 non-null   object
#  3   Decommission_Date  1000 non-null   object
#  4   OS                 1000 non-null   object
#  5   RAM_GB             1000 non-null   int64
#  6   CPU_Cores          1000 non-null   int64
#  7   Storage_GB         1000 non-null   int64
#  8   Availability       1000 non-null   float64
#  9   Failure_Rate       1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.3+ KB
# None
#             RAM_GB    CPU_Cores   Storage_GB  Availability  Failure_Rate
# count  1000.000000  1000.000000  1000.000000   1000.000000   1000.000000
# mean    135.310000    34.727000  2725.365000     74.764220      2.546380
# ...

# %%
df.info()  # Check data types and missing values
df.describe()  # Summary statistics
df["OS"].value_counts()  # Count servers by OS
df["Data_Center"].value_counts()  # Count servers by data center
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Server_ID          1000 non-null   object
#  1   Data_Center        1000 non-null   object
#  2   Purchase_Date      1000 non-null   object
#  3   Decommission_Date  1000 non-null   object
#  4   OS                 1000 non-null   object
#  5   RAM_GB             1000 non-null   int64
#  6   CPU_Cores          1000 non-null   int64
#  7   Storage_GB         1000 non-null   int64
#  8   Availability       1000 non-null   float64
#  9   Failure_Rate       1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.3+ KB
# Data_Center
# Dallas           214
# Atlanta          213
# New York         201
# Chicago          195
# San Francisco    177
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["Failure_Rate"], bins=20, kde=True)
plt.title("Distribution of Server Failure Rate")
plt.xlabel("Failure Rate (%)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="RAM_GB", y="Failure_Rate", hue="OS")
plt.title("RAM vs. Server Failure Rate")
plt.xlabel("RAM (GB)")
plt.ylabel("Failure Rate (%)")
plt.show()
